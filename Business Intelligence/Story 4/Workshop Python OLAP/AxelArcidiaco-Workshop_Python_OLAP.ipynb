# %% [markdown]
# ## Workshop Python OLAP

# %% [markdown]
# # Importations

# %%
# Importation des modules et bibliothèques Python
import numpy as np
import pandas as pd
import seaborn as sns
import atoti as tt
# Out:
# Welcome to atoti 0.7.2!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %% [markdown]
# # CSV vins rouges

# %%
# Chargement du fichier winequality-red.csv
wine_red = pd.read_csv("https://data.atoti.io/notebooks/wine-analytics/winequality-red.csv", sep=";")

# Affichage des premières lignes (5) du dataframe wine_red
wine_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # CSV vins blancs

# %%
# Chargement du fichier winequality-white.csv
wine_white = pd.read_csv(
    "https://data.atoti.io/notebooks/wine-analytics/winequality-white.csv",
    sep=";")

# Affichage des premières lignes (5) du dataframe wine_white
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# # Fusion des deux dataframes en un seul et unique dataframe pour les charger dans atoti

# %%
wine_red["category"]= "Red"
wine_white["category"]= "White"

wines = pd.concat([wine_red, wine_white], ignore_index = True)
wines.index.set_names("wine index", inplace=True)
wines.head()
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine index
# 0                     7.4              0.70         0.00             1.9
# 1                     7.8              0.88         0.00             2.6
# 2                     7.8              0.76         0.04             2.3
# 3                    11.2              0.28         0.56             1.9
# 4                     7.4              0.70         0.00             1.9
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# wine index
# 0               0.076                 11.0                  34.0   0.9978
# 1               0.098                 25.0                  67.0   0.9968
# 2               0.092                 15.0                  54.0   0.9970
# 3               0.075                 17.0                  60.0   0.9980
# 4               0.076                 11.0                  34.0   0.9978
#
#               pH  sulphates  alcohol  quality category
# ...

# %%
wines["alcohol range"] = wines["alcohol"].apply(np.floor)

# %%
wines["Rating"]= "Good"
wines.loc[wines["quality"]< 7, "Rating"] = "Average"
wines.loc[wines["quality"]< 5, "Rating"] = "Poor"
wines
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine index
# 0                     7.4              0.70         0.00             1.9
# 1                     7.8              0.88         0.00             2.6
# 2                     7.8              0.76         0.04             2.3
# 3                    11.2              0.28         0.56             1.9
# 4                     7.4              0.70         0.00             1.9
# ...                   ...               ...          ...             ...
# 6492                  6.2              0.21         0.29             1.6
# 6493                  6.6              0.32         0.36             8.0
# 6494                  6.5              0.24         0.19             1.2
# 6495                  5.5              0.29         0.30             1.1
# 6496                  6.0              0.21         0.38             0.8
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %% [markdown]
# # Utilisation de Atoti

# %%
# Création d'une session atoti
session = tt.Session(user_content_storage="./content_full")
