# %% [markdown]
# # **Préparation des données**

# %%
# Importation des bibliotheques Python
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Importation des données
df_train = pd.read_csv("./Data/train.csv")
df_test = pd.read_csv("./Data/test.csv")

# %%
# Visualisation des données
df_test
# Out:
#                                                    Name    Location  Year  \
# 0                               Maruti Alto K10 LXI CNG       Delhi  2014
# 1                         Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2             Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                                  Toyota Etios Liva GD   Hyderabad  2012
# 4                                     Hyundai i20 Magna      Mumbai  2014
# ...                                                 ...         ...   ...
# 1229                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 1230                             Volkswagen Polo GT TSI      Mumbai  2015
# 1231                             Nissan Micra Diesel XV     Kolkata  2012
# 1232                             Volkswagen Polo GT TSI        Pune  2013
# 1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# 0                 40929       CNG       Manual      First  32.26 km/kg
# 1                 54493    Petrol       Manual     Second    24.7 kmpl
# 2                 34000    Diesel       Manual      First   13.68 kmpl
# 3                139000    Diesel       Manual      First   23.59 kmpl
# 4                 29000    Petrol       Manual      First    18.5 kmpl
# ...                 ...       ...          ...        ...          ...
# 1229              89411    Diesel       Manual      First   20.54 kmpl
# 1230              59000    Petrol    Automatic      First   17.21 kmpl
# 1231              28000    Diesel       Manual      First   23.08 kmpl
# 1232              52262    Petrol    Automatic      Third    17.2 kmpl
# 1233              72443    Diesel    Automatic      First    10.0 kmpl
#
#        Engine      Power  Seats   New_Price
# 0      998 CC   58.2 bhp    4.0         NaN
# 1      796 CC   47.3 bhp    5.0         NaN
# 2     2393 CC  147.8 bhp    7.0  25.27 Lakh
# 3     1364 CC   null bhp    5.0         NaN
# 4     1197 CC  82.85 bhp    5.0         NaN
# ...       ...        ...    ...         ...
# 1229  1598 CC  103.6 bhp    5.0         NaN
# 1230  1197 CC  103.6 bhp    5.0         NaN
# 1231  1461 CC   63.1 bhp    5.0         NaN
# 1232  1197 CC  103.6 bhp    5.0         NaN
# 1233  2148 CC    170 bhp    5.0         NaN
#
# [1234 rows x 12 columns]

# %%
df_train
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       New_Price  Price
# 0           NaN   1.75
# 1           NaN  12.50
# 2     8.61 Lakh   4.50
# 3           NaN   6.00
# 4           NaN  17.74
# ...         ...    ...
# 6014  7.88 Lakh   4.75
# 6015        NaN   4.00
# 6016        NaN   2.90
# 6017        NaN   2.65
# 6018        NaN   2.50
#
# [6019 rows x 13 columns]

# %%
df_train.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
df_train.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
# Affichage du nombre de NaN par colonnes
pd.isnull(df_train).sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %% [markdown]
# On peut voir sur le tableau ci-dessus que la/les colonne(s): New_Price contient 5195 valeurs null, Engine et Power contiennent 36 valeurs null,  Seats 42 valeurs null, et Mileage 2 valeurs null.
# Etant données la quantité de données null dans New_Price, il me semble judicieux de supprimer la colonne du dataset df_train avant de modifier ou supprimer les valeurs null des autre colonnes.

# %%
# Modification du dataset
df_train = df_train.drop(columns=['New_Price'])
df_train = df_train.dropna()
df_train
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5975 rows x 12 columns]

# %%
# Vérification de l'abscence de NaN après modification du dataset
pd.isnull(df_train).sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
# Affichage de la 1ère matrice de collération
corr = df_train.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap,  center=0, square=True, linewidths=.5,cbar_kws={"shrink": .5},  annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# La matrice de corrélation ci-dessus n'utilise que les colonnes de notre dataset qui contiennent des valeurs numériques (4/12 après le retrait de la colonne New_Price). Cela signifie que ses résultats ne sont pas représentatif de notre dataset et que nous allons devoir transformer certaines ou toutes les colonnes de type objet pour améliorer notre matrice.

# %%
# Analyse des colonnes de type object
df_train.Name.value_counts()
# Out:
# Mahindra XUV500 W8 2WD           49
# Maruti Swift VDI                 45
# Honda City 1.5 S MT              34
# Maruti Swift Dzire VDI           34
# Maruti Swift VDI BSIV            31
#                                  ..
# Ford Fiesta Titanium 1.5 TDCi     1
# Mahindra Scorpio S10 AT 4WD       1
# Hyundai i20 1.2 Era               1
# Toyota Camry W4 (AT)              1
# Mahindra Xylo D4 BSIV             1
# Name: Name, Length: 1855, dtype: int64

# %%
df_train.Location.value_counts()
# Out:
# Mumbai        784
# Hyderabad     741
# Kochi         648
# Coimbatore    634
# Pune          613
# Delhi         549
# Kolkata       530
# Chennai       490
# Jaipur        410
# Bangalore     353
# Ahmedabad     223
# Name: Location, dtype: int64

# %%
df_train.Fuel_Type.value_counts()
# Out:
# Diesel    3195
# Petrol    2714
# CNG         56
# LPG         10
# Name: Fuel_Type, dtype: int64

# %%
df_train.Transmission.value_counts()
# Out:
# Manual       4266
# Automatic    1709
# Name: Transmission, dtype: int64

# %%
df_train.Owner_Type.value_counts()
# Out:
# First             4903
# Second             953
# Third              111
# Fourth & Above       8
# Name: Owner_Type, dtype: int64

# %%
df_train.Engine.value_counts()
# Out:
# 1197 CC    606
# 1248 CC    512
# 1498 CC    303
# 998 CC     259
# 2179 CC    240
#           ...
# 1489 CC      1
# 1422 CC      1
# 1978 CC      1
# 2694 CC      1
# 1797 CC      1
# Name: Engine, Length: 145, dtype: int64

# %%
df_train.Power.value_counts()
# Out:
# 74 bhp        235
# 98.6 bhp      131
# 73.9 bhp      125
# 140 bhp       123
# 78.9 bhp      111
#              ...
# 201 bhp         1
# 199.3 bhp       1
# 95 bhp          1
# 152.88 bhp      1
# 181.04 bhp      1
# Name: Power, Length: 371, dtype: int64

# %%
# Modification des colonnes de type object en colonnes de type float ou int
location_code = {
    'Mumbai': 1,
    'Hyderabad': 2,
    'Kochi': 3,
    'Coimbatore': 4,
    'Pune': 5,
    'Dehli': 6,
    'Kolkata': 7,
    'Chennai': 8,
    'Jaipur': 9,
    'Bangalore': 10,
    'Ahmedabad': 11,
}

fuel_code = {
    'Diesel': 1,
    'Petrol': 2,
    'CNG': 3,
    'PLG': 4,
}

transmission_code = {
    'Manual': 1,
    'Automatic': 2,
}

owner_code = {
    'First': 1,
    'Second': 2,
    'Third': 3,
    'Fourth & Above': 4,
}

df_train['Location'] = df_train['Location'].map(location_code)
df_train['Fuel_Type'] = df_train['Fuel_Type'].map(fuel_code)
df_train['Transmission'] = df_train['Transmission'].map(transmission_code)
df_train['Owner_Type'] = df_train['Owner_Type'].map(owner_code)
df_train.dropna()
df_train
# Out:
#                                   Name  Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG       1.0  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option       5.0  2015              41000
# 2                         Honda Jazz V       8.0  2011              46000
# 3                    Maruti Ertiga VDI       8.0  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic       4.0  2013              40670
# ...                                ...       ...   ...                ...
# 6014                  Maruti Swift VDI       NaN  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S       9.0  2015             100000
# 6016             Mahindra Xylo D4 BSIV       9.0  2012              55000
# 6017                Maruti Wagon R VXI       7.0  2013              46000
# 6018             Chevrolet Beat Diesel       2.0  2011              47000
#
#       Fuel_Type  Transmission  Owner_Type     Mileage   Engine      Power  \
# 0           3.0             1           1  26.6 km/kg   998 CC  58.16 bhp
# 1           1.0             1           1  19.67 kmpl  1582 CC  126.2 bhp
# 2           2.0             1           1   18.2 kmpl  1199 CC   88.7 bhp
# 3           1.0             1           1  20.77 kmpl  1248 CC  88.76 bhp
# 4           1.0             2           2   15.2 kmpl  1968 CC  140.8 bhp
# ...         ...           ...         ...         ...      ...        ...
# 6014        1.0             1           1   28.4 kmpl  1248 CC     74 bhp
# 6015        1.0             1           1   24.4 kmpl  1120 CC     71 bhp
# 6016        1.0             1           2   14.0 kmpl  2498 CC    112 bhp
# 6017        2.0             1           1   18.9 kmpl   998 CC   67.1 bhp
# 6018        1.0             1           1  25.44 kmpl   936 CC   57.6 bhp
#
#       Seats  Price
# 0       5.0   1.75
# 1       5.0  12.50
# 2       5.0   4.50
# 3       7.0   6.00
# 4       5.0  17.74
# ...     ...    ...
# 6014    5.0   4.75
# 6015    5.0   4.00
# 6016    8.0   2.90
# 6017    5.0   2.65
# 6018    5.0   2.50
#
# [5975 rows x 12 columns]

# %%
# Affichage d'une 2ème matrice de collération
corr = df_train.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap,  center=0, square=True, linewidths=.5,cbar_kws={"shrink": .5},  annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Cette matrice de corrélation est meilleur que la première matrice généré

# %%
# Suppression des unités de mesures dans les colonnes Engine & Power
df_train['Engine'] = df_train['Engine'].str.replace(' CC', '')
df_train['Power'] = df_train['Power'].str.replace(' bhp', '')

# Conversion en float des données des colonnes Engine & Power
df_train['Engine'] = pd.to_numeric(df_train['Engine'], errors='coerce')
df_train['Power'] = pd.to_numeric(df_train['Power'], errors='coerce')

# Changement du nom des colonnes Engine & Power pour inclure les unités de mesures correspondantes
df_train = df_train.rename(columns={'Engine': 'Engine (in CC)', 'Power': 'Power (in bhp)'})

# %%
# Affichage d'une 3ème matrice de collération
corr = df_train.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap,  center=0, square=True, linewidths=.5,cbar_kws={"shrink": .5},  annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Avec cette troisième matrice de corrélation, on constate que le prix d'une voiture est fortement corrélé avec l'année de production, la transmission, le moteur, et la puissance moteur de celle-ci donc on peut dire que ces quatre features sont les plus importantes.
# De plus le moteur et la puissance moteur sont fortement corrélé entre eux donc il serait sage de ne retenir qu'une seule de ces deux features pour l'entrainement du modèle et donc on va retenir Power car sa corrélation avec Price est plus grande que Engine.

# %%
# Affichage du nombre de ligne en km/kg et kmpl
kmkg = 0
kmpl = 0
for i in df_train.Mileage:
    if str(i).endswith("km/kg"):
        kmkg+=1
    elif str(i).endswith("kmpl"):
        kmpl+=1
print('Nombre de lignes avec Km/Kg : {} '.format(kmkg))
print('Nombre de lignes avec kmpl : {} '.format(kmpl))
# Out:
# Nombre de lignes avec Km/Kg : 66
# Nombre de lignes avec kmpl : 5909

# %%
# Conversion des mileage en km/kg en mileage en kmpl
Correct_Mileage= []
for i in df_train.Mileage:
    if str(i).endswith('km/kg'):
        i = i[:-6]
        i = float(i)*1.40
        Correct_Mileage.append(float(i))
    elif str(i).endswith('kmpl'):
        i = i[:-6]
        #print(i)
        Correct_Mileage.append(float(i))
        
df_train['Mileage']=Correct_Mileage
df_train = df_train.rename(columns={'Mileage':'Mileage in kmpl'})
df_train
# Out:
#                                   Name  Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG       1.0  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option       5.0  2015              41000
# 2                         Honda Jazz V       8.0  2011              46000
# 3                    Maruti Ertiga VDI       8.0  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic       4.0  2013              40670
# ...                                ...       ...   ...                ...
# 6014                  Maruti Swift VDI       NaN  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S       9.0  2015             100000
# 6016             Mahindra Xylo D4 BSIV       9.0  2012              55000
# 6017                Maruti Wagon R VXI       7.0  2013              46000
# 6018             Chevrolet Beat Diesel       2.0  2011              47000
#
#       Fuel_Type  Transmission  Owner_Type  Mileage in kmpl  Engine (in CC)  \
# 0           3.0             1           1            37.24             998
# 1           1.0             1           1            19.60            1582
# 2           2.0             1           1            18.00            1199
# 3           1.0             1           1            20.70            1248
# 4           1.0             2           2            15.00            1968
# ...         ...           ...         ...              ...             ...
# 6014        1.0             1           1            28.00            1248
# 6015        1.0             1           1            24.00            1120
# 6016        1.0             1           2            14.00            2498
# 6017        2.0             1           1            18.00             998
# 6018        1.0             1           1            25.40             936
#
#       Power (in bhp)  Seats  Price
# 0              58.16    5.0   1.75
# 1             126.20    5.0  12.50
# 2              88.70    5.0   4.50
# 3              88.76    7.0   6.00
# 4             140.80    5.0  17.74
# ...              ...    ...    ...
# 6014           74.00    5.0   4.75
# 6015           71.00    5.0   4.00
# 6016          112.00    8.0   2.90
# 6017           67.10    5.0   2.65
# 6018           57.60    5.0   2.50
#
# [5975 rows x 12 columns]

# %%
# Affichage d'une 4ème matrice de collération
corr = df_train.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap,  center=0, square=True, linewidths=.5,cbar_kws={"shrink": .5},  annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Comme sur la troisième matrice de corrélation, on constate que le prix d'une voiture est fortement corrélé avec l'année de production, la transmission, le moteur, et la puissance moteur de celle-ci donc on peut dire que ces quatre features sont les plus importantes.
# De plus le moteur et la puissance moteur sont fortement corrélé entre eux donc il serait sage de ne retenir qu'une seule de ces deux features pour l'entrainement du modèle et donc on va retenir Power car sa corrélation avec Price est plus grande que Engine.

# %%
pd.isnull(df_train).sum()
# Out:
# Name                   0
# Location             549
# Year                   0
# Kilometers_Driven      0
# Fuel_Type             10
# Transmission           0
# Owner_Type             0
# Mileage in kmpl        0
# Engine (in CC)         0
# Power (in bhp)       103
# Seats                  0
# Price                  0
# dtype: int64

# %%
df_train = df_train.dropna()

# %% [markdown]
# # **Entrainement des modèles**

# %%
# Chargement et nettoyage de test.csv
df_test = pd.read_csv("./Data/test.csv")

df_test = df_test.drop(columns=['New_Price'])
df_test = df_test.dropna()

location_code = {
    'Mumbai': 1,
    'Hyderabad': 2,
    'Kochi': 3,
    'Coimbatore': 4,
    'Pune': 5,
    'Dehli': 6,
    'Kolkata': 7,
    'Chennai': 8,
    'Jaipur': 9,
    'Bangalore': 10,
    'Ahmedabad': 11,
}

fuel_code = {
    'Diesel': 1,
    'Petrol': 2,
    'CNG': 3,
    'PLG': 4,
    'Electric': 5,
}

transmission_code = {
    'Manual': 1,
    'Automatic': 2,
}

owner_code = {
    'First': 1,
    'Second': 2,
    'Third': 3,
    'Fourth & Above': 4,
}

df_test['Location'] = df_test['Location'].map(location_code)
df_test['Fuel_Type'] = df_test['Fuel_Type'].map(fuel_code)
df_test['Transmission'] = df_test['Transmission'].map(transmission_code)
df_test['Owner_Type'] = df_test['Owner_Type'].map(owner_code)

# Suppression des unités de mesures dans les colonnes Engine & Power
df_test['Engine'] = df_test['Engine'].str.replace(' CC', '')
df_test['Power'] = df_test['Power'].str.replace(' bhp', '')

# Conversion en float des données des colonnes Engine & Power
df_test['Engine'] = pd.to_numeric(df_test['Engine'], errors='coerce')
df_test['Power'] = pd.to_numeric(df_test['Power'], errors='coerce')

# Changement du nom des colonnes Engine & Power pour inclure les unités de mesures correspondantes
df_test = df_test.rename(columns={'Engine': 'Engine (in CC)', 'Power': 'Power (in bhp)'})

# Conversion des mileage en km/kg en mileage en kmpl
Correct_Mileage= []
for i in df_test.Mileage:
    if str(i).endswith('km/kg'):
        i = i[:-6]
        i = float(i)*1.40
        Correct_Mileage.append(float(i))
    elif str(i).endswith('kmpl'):
        i = i[:-6]
        #print(i)
        Correct_Mileage.append(float(i))
        
df_test['Mileage']=Correct_Mileage
df_test = df_test.rename(columns={'Mileage':'Mileage in kmpl'})
df_test = df_test.dropna()

# Affichage du dataframe df_test
df_test
# Out:
#                                                    Name  Location  Year  \
# 1                         Maruti Alto 800 2016-2019 LXI       4.0  2013
# 2             Toyota Innova Crysta Touring Sport 2.4 MT       1.0  2017
# 4                                     Hyundai i20 Magna       1.0  2014
# 5                                Mahindra XUV500 W8 2WD       4.0  2016
# 6                   Toyota Fortuner 4x2 AT TRD Sportivo       5.0  2015
# ...                                                 ...       ...   ...
# 1229                  Volkswagen Vento Diesel Trendline       2.0  2011
# 1230                             Volkswagen Polo GT TSI       1.0  2015
# 1231                             Nissan Micra Diesel XV       7.0  2012
# 1232                             Volkswagen Polo GT TSI       5.0  2013
# 1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       3.0  2014
#
#       Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  Mileage in kmpl  \
# 1                 54493        2.0             1           2             24.0
# 2                 34000        1.0             1           1             13.6
# 4                 29000        2.0             1           1             18.0
# 5                 85609        1.0             1           2             16.0
# 6                 59000        1.0             2           1             12.5
# ...                 ...        ...           ...         ...              ...
# 1229              89411        1.0             1           1             20.5
# 1230              59000        2.0             2           1             17.2
# 1231              28000        1.0             1           1             23.0
# 1232              52262        2.0             2           3             17.0
# 1233              72443        1.0             2           1             10.0
#
#       Engine (in CC)  Power (in bhp)  Seats
# 1                796           47.30    5.0
# 2               2393          147.80    7.0
# 4               1197           82.85    5.0
# 5               2179          140.00    7.0
# 6               2982          168.70    7.0
# ...              ...             ...    ...
# 1229            1598          103.60    5.0
# 1230            1197          103.60    5.0
# 1231            1461           63.10    5.0
# 1232            1197          103.60    5.0
# 1233            2148          170.00    5.0
#
# [1094 rows x 11 columns]

# %%
# Importation des bibliothèques scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# La target est la colonne "Price". Ici, on garde toutes les features
X_full = df_train.drop(columns=['Name','Price'], axis= 0)

# La target est la colonne "Price". Ici, on ne garde que les features qui ont une importante corrélation avec "Price"
X_restraint = df_train.drop(columns=[
    'Name', 
    'Location',
    'Kilometers_Driven',
    'Fuel_Type',
    'Owner_Type',
    'Mileage in kmpl',
    'Engine (in CC)',
    'Seats',
    'Price'
], axis = 0)

# %%
pd.isnull(X_full).sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage in kmpl      0
# Engine (in CC)       0
# Power (in bhp)       0
# Seats                0
# dtype: int64

# %%
import pickle

# fonction d'exportation des modèles
def export_model(model_name, model):
    path = "./Models/"
    ext= ".pkl"
    pickle.dump(model, open(path + model_name + ext, 'wb'))

# %%
# suppression de tout NaN restant
X_full.dropna()
X_restraint.dropna()

# Définition de la target
y = df_train['Price']

# Séparation des données
X_full_train, X_full_test, y_full_train, y_full_test = train_test_split(X_full, y, test_size= 0.2, random_state= 42)
X_restraint_train, X_restraint_test, y_restraint_train, y_restraint_test = train_test_split(X_restraint, y, test_size= 0.2, random_state= 42)

# %%
# function the return metrics of linear regression
def linearRegression(X_train, X_test, y_train, y_test):

    # Training the Multiple Linear Regression model on the Training set
    regressor = LinearRegression()
    regressor.fit(X_train, y_train)
    # Predicting the Test set results
    y_pred = regressor.predict(X_test)
    coef = regressor.coef_
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    adj_r2 = 1 - (1 - r2)*(X_test.shape[0] - 1) / \
        (X_test.shape[0] - X_test.shape[1]-1)
    print('Coefficients : ', coef)
    print('MAE : ', mae)
    print('MSE : ', mse)
    print('RMSE : ', rmse)
    print('R² : ', r2)
    print('Adjusted R² : ', adj_r2)
    return [mae, mse, rmse, r2, adj_r2]

# %%
# Evaluation des modèles de regression linéaire :
# avec toutes les features utilisés
print("Evaluation du modèle de regression linéaire qui utilise toutes les features:")
full_regression = linearRegression(X_full_train, X_full_test, y_full_train, y_full_test)
print()

# avec seulement les features : Year, Transmission, Power (in bhp)
print("Evaluation du modèle de regression linéaire qui utilise les features : Year, Transmission, Power (in bhp)") 
restraint_regression = linearRegression(X_restraint_train, X_restraint_test, y_restraint_train, y_restraint_test)
# Out:
# Evaluation du modèle de regression linéaire qui utilise toutes les features:
# Coefficients :  [ 1.08236288e-02  1.00430322e+00  2.13054192e-06 -1.96674026e+00
#   2.89626848e+00 -2.43843589e-01 -8.82619156e-02  9.88194101e-04
#   1.27440258e-01 -7.79675756e-01]
# MAE :  3.7999818837481336
# MSE :  36.14137478987217
# RMSE :  6.011769688691689
# R² :  0.6880571685314922
# Adjusted R² :  0.6850947484795595
#
# Evaluation du modèle de regression linéaire qui utilise les features : Year, Transmission, Power (in bhp)
# Coefficients :  [0.98091854 2.88926917 0.14547562]
# MAE :  3.865423364394576
# MSE :  37.10139833061012
# RMSE :  6.091091719109976
# R² :  0.6797710293540158
# Adjusted R² :  0.6788647209465272

# %%
# SVR
SVR_full = make_pipeline(StandardScaler(), SVR(kernel="rbf", C=1.0, epsilon=0.2))

SVR_full.fit(X_full_train, y_full_train)
y_pred_full = SVR_full.predict(X_full_test)

print("SVR avec toutes les features :")
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("SVR_full", SVR_full)

print()
print("================================================")
print()

print("SVR avec les features Year, Transmission, Power (in bhp) :")
SVR_restraint = make_pipeline(StandardScaler(), SVR(kernel="rbf", C=1.0, epsilon=0.2))
SVR_restraint.fit(X_restraint_train, y_restraint_train)
y_pred_restraint = SVR_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("SVR_restraint", SVR_restraint)
# Out:
# SVR avec toutes les features :
# MAE: 2.2758044390650904
# RMSE: 5.771173263973603
# MSE: 33.30644084280373
# R²: 0.712526003146011
# Adjusted R²: 0.7097959556925069
#
# ================================================
#
# SVR avec les features Year, Transmission, Power (in bhp) :
# MAE: 2.3660668745545244
# RMSE: 5.111181016966489
# MSE: 26.124171388198594
# R²: 0.7745174875061229
# Adjusted R²: 0.7723761531044717

# %%
# RidgeCV regression
from sklearn.linear_model import RidgeCV

# Avec toutes les features
print("RidgeCV avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
ridge_full = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = ridge_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ridge_full", ridge_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("RidgeCV avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
ridge_restraint = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = ridge_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ridge_restraint", ridge_restraint)
# Out:
# RidgeCV avec toutes les features :
# MAE: 3.801495687934724
# RMSE: 6.010032557366857
# MSE: 36.12049134060961
# R²: 0.6882374174105585
# Adjusted R²: 0.6852767091238592
#
# ================================================
#
# RidgeCV avec les features Year, Transmission, et Power :
# MAE: 3.8654231147603904
# RMSE: 6.091112231302453
# MSE: 37.101648214322346
# R²: 0.6797688725618853
# Adjusted R²: 0.6767277412471834

# %%
# DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor

# DecisionTreeRegressor avec toutes les features
print("DecisionTreeRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
tree_full = DecisionTreeRegressor(random_state=42)
tree_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = tree_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("tree_full", tree_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("DecisionTreeRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
tree_restraint = DecisionTreeRegressor(random_state=42)
y_pred_restraint = tree_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = tree_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("tree_restraint", tree_restraint)
# Out:
# DecisionTreeRegressor avec toutes les features :
# MAE: 2.0765836466165415
# RMSE: 5.005961725388302
# MSE: 25.05965279605263
# R²: 0.7837055426289716
# Adjusted R²: 0.781651464211393
#
# ================================================
#
# DecisionTreeRegressor avec les features Year, Transmission, et Power :
# MAE: 1.8779687968822625
# RMSE: 4.599585682378992
# MSE: 21.156188449545812
# R²: 0.817397059010549
# Adjusted R²: 0.8156629380134982

# %%
# RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# RandomForestRegressor avec toutes les features
print("RandomForestRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
random_forest_full = RandomForestRegressor(max_depth=2, random_state=42)
random_forest_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = random_forest_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("random_forest_full", random_forest_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("RandomForestRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
random_forest_restraint = RandomForestRegressor(max_depth=2, random_state=42)
y_pred_restraint = random_forest_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = random_forest_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("random_forest_restraint", random_forest_restraint)
# Out:
# RandomForestRegressor avec toutes les features :
# MAE: 3.6003988144531456
# RMSE: 6.258483153650722
# MSE: 39.168611384529896
# R²: 0.6619285345115368
# Adjusted R²: 0.6587179792837261
#
# ================================================
#
# RandomForestRegressor avec les features Year, Transmission, et Power :
# MAE: 3.66041109297013
# RMSE: 6.306827003709078
# MSE: 39.77606685471402
# R²: 0.6566854749859381
# Adjusted R²: 0.6534251281197077

# %%
# LassoCV
from sklearn.linear_model import LassoCV

# LassoCV avec toutes les features
print("LassoCV avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
LassoCV_full = LassoCV(cv=5, random_state=42)
LassoCV_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = LassoCV_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)
# Affichage des paramètres du model
print("Params :", LassoCV_full.get_params())

# exportation du modèle
export_model("LassoCV_full", LassoCV_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("LassoCV avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
LassoCV_restraint = LassoCV(cv=5, random_state=42)
y_pred_restraint = LassoCV_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = LassoCV_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)
# Affichage des paramètres du model
print("Params :", LassoCV_restraint.get_params())

# exportation du modèle
export_model("LassoCV_restraint", LassoCV_restraint)
# Out:
# LassoCV avec toutes les features :
# MAE: 4.106758801052724
# RMSE: 6.929471597828828
# MSE: 48.017576625116405
# R²: 0.5855514932737891
# Adjusted R²: 0.5816156100190293
# Params : {'alphas': None, 'copy_X': True, 'cv': 5, 'eps': 0.001, 'fit_intercept': True, 'max_iter': 1000, 'n_alphas': 100, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False, 'precompute': 'auto', 'random_state': 42, 'selection': 'cyclic', 'tol': 0.0001, 'verbose': False}
#
# ================================================
#
# LassoCV avec les features Year, Transmission, et Power :
# MAE: 3.9128260259464724
# RMSE: 6.187151419573954
# MSE: 38.280842688736
# R²: 0.6695910288761024
# Adjusted R²: 0.6664532418758755
# Params : {'alphas': None, 'copy_X': True, 'cv': 5, 'eps': 0.001, 'fit_intercept': True, 'max_iter': 1000, 'n_alphas': 100, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False, 'precompute': 'auto', 'random_state': 42, 'selection': 'cyclic', 'tol': 0.0001, 'verbose': False}

# %%
# GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor

# GradientBoostingRegressor avec toutes les features
print("GradientBoostingRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
GradientBoostingRegressor_full = GradientBoostingRegressor(random_state=42)
GradientBoostingRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = GradientBoostingRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("GradientBoostingRegressor_full", GradientBoostingRegressor_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("GradientBoostingRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
GradientBoostingRegressor_restraint = GradientBoostingRegressor(random_state=42)
y_pred_restraint = GradientBoostingRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = GradientBoostingRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("GradientBoostingRegressor_restraint", GradientBoostingRegressor_restraint)
# Out:
# GradientBoostingRegressor avec toutes les features :
# MAE: 1.821954151699717
# RMSE: 3.7200372172375777
# MSE: 13.8386768976327
# R²: 0.8805558427059316
# Adjusted R²: 0.8794215202245064
#
# ================================================
#
# GradientBoostingRegressor avec les features Year, Transmission, et Power :
# MAE: 2.073166108896162
# RMSE: 4.378842898274988
# MSE: 19.174265127773296
# R²: 0.8345034025390314
# Adjusted R²: 0.8329317349468095

# %%
# Neural Network
from sklearn.neural_network import MLPRegressor

# MLPRegressor avec toutes les features
print("MLPRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
MLPRegressor_full = MLPRegressor(random_state=42, max_iter=100)
MLPRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = MLPRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("MLPRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
MLPRegressor_restraint = MLPRegressor(random_state=42, max_iter=100)
y_pred_restraint = MLPRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = MLPRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)
# Out:
# MLPRegressor avec toutes les features :
# MAE: 35.21618732094795
# RMSE: 53.28323874271954
# MSE: 2839.1035309136487
# R²: -23.50482305708034
# Adjusted R²: -23.737537426093446
#
# ================================================
#
# MLPRegressor avec les features Year, Transmission, et Power :
# MAE: 3.8121633789879277
# RMSE: 6.680870295601996
# MSE: 44.6340279066571
# R²: 0.6147555225555863
# Adjusted R²: 0.6110969805095805

# %%
# AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor

# AdaBoostRegressor avec toutes les features
print("AdaBoostRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
ada_full = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300,random_state=42)
ada_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = ada_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ada_full", ada_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("AdaBoostRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
ada_restraint = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300,random_state=42)
y_pred_restraint = ada_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = ada_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ada_restraint", ada_restraint)
# Out:
# AdaBoostRegressor avec toutes les features :
# MAE: 5.5644497917289435
# RMSE: 6.429502519030684
# MSE: 41.338502642221904
# R²: 0.6431998052687053
# Adjusted R²: 0.6398113893643246
#
# ================================================
#
# AdaBoostRegressor avec les features Year, Transmission, et Power :
# MAE: 2.6135023853675454
# RMSE: 4.84275979965723
# MSE: 23.452322477176136
# R²: 0.797578705276786
# Adjusted R²: 0.795656375792235

# %%
# BaggingRegressor
from sklearn.ensemble import BaggingRegressor

# BaggingRegressor avec toutes les features
print("BaggingRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
bagging_regressor_full = BaggingRegressor(random_state=42)
bagging_regressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = bagging_regressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("bagging_regressor_full", bagging_regressor_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("BaggingRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
bagging_regressor_restraint = BaggingRegressor(random_state=42)
y_pred_restraint = bagging_regressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = bagging_regressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("bagging_regressor_restraint", bagging_regressor_restraint)
# Out:
# BaggingRegressor avec toutes les features :
# MAE: 1.6115175438596492
# RMSE: 3.649068879715725
# MSE: 13.315703688909775
# R²: 0.8850697203450555
# Adjusted R²: 0.88397826469781
#
# ================================================
#
# BaggingRegressor avec les features Year, Transmission, et Power :
# MAE: 1.7226674922282499
# RMSE: 3.804857181132863
# MSE: 14.476938168818316
# R²: 0.8750468926643818
# Adjusted R²: 0.8738602534684121

# %%
# KNeighbourRegressor
from sklearn.neighbors import KNeighborsRegressor

# KNeighborsRegressor avec toutes les features
print("KNeighborsRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
KNeighborsRegressor_full = KNeighborsRegressor(n_neighbors=2)
KNeighborsRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = KNeighborsRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("KNeighborsRegressor_full", KNeighborsRegressor_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("KNeighborsRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
KNeighborsRegressor_restraint = KNeighborsRegressor(n_neighbors=2)
y_pred_restraint = KNeighborsRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = KNeighborsRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("KNeighborsRegressor_restraint", KNeighborsRegressor_restraint)
# Out:
# KNeighborsRegressor avec toutes les features :
# MAE: 4.168359962406015
# RMSE: 7.496465296444016
# MSE: 56.19699194078947
# R²: 0.5149534601839427
# Adjusted R²: 0.5103471302711597
#
# ================================================
#
# KNeighborsRegressor avec les features Year, Transmission, et Power :
# MAE: 2.0225657894736844
# RMSE: 4.4467058644701005
# MSE: 19.773193045112784
# R²: 0.8293339458853579
# Adjusted R²: 0.8277131856373556

# %%
# Extra Tree Regressor
from sklearn.ensemble import ExtraTreesRegressor

# ExtraTreesRegressor avec toutes les features
print("ExtraTreesRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
ExtraTreesRegressor_full = ExtraTreesRegressor(n_estimators=100, random_state=42)
ExtraTreesRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = ExtraTreesRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ExtraTreesRegressor_full", ExtraTreesRegressor_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("ExtraTreesRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
ExtraTreesRegressor_restraint = ExtraTreesRegressor(n_estimators=100, random_state=42)
y_pred_restraint = ExtraTreesRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = ExtraTreesRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("ExtraTreesRegressor_restraint", ExtraTreesRegressor_restraint)
# Out:
# ExtraTreesRegressor avec toutes les features :
# MAE: 1.4607085526315786
# RMSE: 3.345182436091204
# MSE: 11.190245530733081
# R²: 0.9034149393602235
# Adjusted R²: 0.9024977023171108
#
# ================================================
#
# ExtraTreesRegressor avec les features Year, Transmission, et Power :
# MAE: 1.9408879458351849
# RMSE: 4.617534757268505
# MSE: 21.32162723458271
# R²: 0.8159691265276491
# Adjusted R²: 0.814221444918225

# %%
# QuantileRegressor
from sklearn.linear_model import QuantileRegressor
from sklearn.utils.fixes import sp_version, parse_version
# Définition du solver
solver = "highs" if sp_version >= parse_version("1.6.0") else "interior-point"

# QuantileRegressor avec toutes les features
print("QuantileRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
QuantileRegressor_full = QuantileRegressor(quantile=0.8, solver=solver)
QuantileRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = QuantileRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("QuantileRegressor_full", QuantileRegressor_full)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("QuantileRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
QuantileRegressor_restraint = QuantileRegressor(quantile=0.8, solver=solver)
y_pred_restraint = QuantileRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = QuantileRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("QuantileRegressor_restraint", QuantileRegressor_restraint)
# Out:
# QuantileRegressor avec toutes les features :
# MAE: 5.432906991289727
# RMSE: 7.987576801454951
# MSE: 63.8013831591413
# R²: 0.4493185654949984
# Adjusted R²: 0.4440889222423392
#
# ================================================
#
# QuantileRegressor avec les features Year, Transmission, et Power :
# MAE: 5.647302514698379
# RMSE: 8.271250129711374
# MSE: 68.41357870825041
# R²: 0.4095098601748366
# Adjusted R²: 0.40390216653927

# %%
# SGDRegressor
from sklearn.linear_model import SGDRegressor

# SGDRegressor avec toutes les features
print("SGDRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
SGDRegressor_full = SGDRegressor(max_iter=1000, tol=1e-3)
SGDRegressor_full.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = SGDRegressor_full.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("SGDRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
SGDRegressor_restraint = SGDRegressor(max_iter=1000, tol=1e-3)
y_pred_restraint = SGDRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = SGDRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)
# Out:
# SGDRegressor avec toutes les features :
# MAE: 2.2752901784698666e+17
# RMSE: 2.445891578099099e+17
# MSE: 5.982385611816101e+34
# R²: -5.163506694297991e+32
# Adjusted R²: -5.212542845240992e+32
#
# ================================================
#
# SGDRegressor avec les features Year, Transmission, et Power :
# MAE: 1735995452307426.2
# RMSE: 1736045064781339.5
# MSE: 3.0138524669516456e+30
# R²: -2.60131131600644e+28
# Adjusted R²: -2.6260151271745927e+28

# %%
# StackingRegressor
from sklearn.ensemble import StackingRegressor

# Estimator
estimators = [
    ('lr', RidgeCV()),
    ('svr', SVR()),
    ('br', BaggingRegressor(random_state=42)),
    ('et', ExtraTreesRegressor(n_estimators=100, random_state=42)),
    ('ada', AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300,random_state=42))
]

# StackingRegressor avec toutes les features
print("StackingRegressor avec toutes les features :")
# Chargement du modèle et ajustement de celui-ci à nos données
StackingRegressor_restraint = StackingRegressor(estimators=estimators, final_estimator=RandomForestRegressor(n_estimators=10, random_state=42))
StackingRegressor_restraint.fit(X_full_train, y_full_train)
# Prédiction
y_pred_full = StackingRegressor_restraint.predict(X_full_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_full_test, y_pred_full)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_full_test, y_pred_full)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_full_test, y_pred_full)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("StackingRegressor_restraint", StackingRegressor_restraint)

print()
print("================================================")
print()

# Avec les features Year, Transmission, et Power (in bhp)
print("StackingRegressor avec les features Year, Transmission, et Power :")
# Chargement du modèle et ajustement de celui-ci à nos données
StackingRegressor_restraint = StackingRegressor(estimators=estimators, final_estimator=RandomForestRegressor(n_estimators=10, random_state=42))
y_pred_restraint = StackingRegressor_restraint.fit(X_restraint_train, y_restraint_train)
# Prédiction
y_pred_restraint = StackingRegressor_restraint.predict(X_restraint_test)
# Calculate mean absolute error (MAE)
mae = mean_absolute_error(y_restraint_test, y_pred_restraint)
print('MAE:', mae)
# Calculate root mean squared error (RMSE)
mse = mean_squared_error(y_restraint_test, y_pred_restraint)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Calculate mean squared error (MSE)
print('MSE:', mse)
# R²
r2 = r2_score(y_restraint_test, y_pred_restraint)
print("R²:", r2)
# Calculate adjusted R²
n = len(X_full_test)
p = X_full_test.shape[1]  # number of predictors
adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1)
print('Adjusted R²:', adj_r2)

# exportation du modèle
export_model("StackingRegressor_restraint", StackingRegressor_restraint)
# Out:
# StackingRegressor avec toutes les features :
# MAE: 1.6537772556390977
# RMSE: 3.482699898051398
# MSE: 12.129198579887216
# R²: 0.895310663458378
# Adjusted R²: 0.894316462731487
#
# ================================================
#
# StackingRegressor avec les features Year, Transmission, et Power :
# MAE: 1.931855663528447
# RMSE: 4.103788296259161
# MSE: 16.841078380513665
# R²: 0.8546415650886454
# Adjusted R²: 0.8532611431046819

# %% [markdown]
# # Test des modèles sur les données de test.csv

# %%
df_test.drop(columns=['Name'], axis=0)
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 1          4.0  2013              54493        2.0             1           2
# 2          1.0  2017              34000        1.0             1           1
# 4          1.0  2014              29000        2.0             1           1
# 5          4.0  2016              85609        1.0             1           2
# 6          5.0  2015              59000        1.0             2           1
# ...        ...   ...                ...        ...           ...         ...
# 1229       2.0  2011              89411        1.0             1           1
# 1230       1.0  2015              59000        2.0             2           1
# 1231       7.0  2012              28000        1.0             1           1
# 1232       5.0  2013              52262        2.0             2           3
# 1233       3.0  2014              72443        1.0             2           1
#
#       Mileage in kmpl  Engine (in CC)  Power (in bhp)  Seats
# 1                24.0             796           47.30    5.0
# 2                13.6            2393          147.80    7.0
# 4                18.0            1197           82.85    5.0
# 5                16.0            2179          140.00    7.0
# 6                12.5            2982          168.70    7.0
# ...               ...             ...             ...    ...
# 1229             20.5            1598          103.60    5.0
# 1230             17.2            1197          103.60    5.0
# 1231             23.0            1461           63.10    5.0
# 1232             17.0            1197          103.60    5.0
# 1233             10.0            2148          170.00    5.0
#
# [1094 rows x 10 columns]

# %% [markdown]
# # Graphiques

# %%
sns.pairplot(df_train)
