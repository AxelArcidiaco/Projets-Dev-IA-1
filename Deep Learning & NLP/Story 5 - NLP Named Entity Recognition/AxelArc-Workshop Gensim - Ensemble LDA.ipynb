# %% [markdown]
# # Ensemble LDA

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # Corpus

# %%
import gensim.downloader as api
from gensim.corpora import Dictionary
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = api.load('text8')

dictionary = Dictionary()
for doc in docs:
    dictionary.add_documents([[lemmatizer.lemmatize(token) for token in doc]])
dictionary.filter_extremes(no_below=20, no_above=0.5)

corpus = [dictionary.doc2bow(doc) for doc in docs]
# Out:
# 2023-04-04 14:30:15,409 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2023-04-04 14:30:15,426 : INFO : built Dictionary<2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1 documents (total 10000 corpus positions)
# 2023-04-04 14:30:15,555 : INFO : adding document #0 to Dictionary<2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:15,573 : INFO : built Dictionary<3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 2 documents (total 20000 corpus positions)
# 2023-04-04 14:30:15,692 : INFO : adding document #0 to Dictionary<3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:15,719 : INFO : built Dictionary<5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 3 documents (total 30000 corpus positions)
# 2023-04-04 14:30:15,846 : INFO : adding document #0 to Dictionary<5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:15,865 : INFO : built Dictionary<6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 4 documents (total 40000 corpus positions)
# 2023-04-04 14:30:15,974 : INFO : adding document #0 to Dictionary<6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:15,991 : INFO : built Dictionary<7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 5 documents (total 50000 corpus positions)
# 2023-04-04 14:30:16,098 : INFO : adding document #0 to Dictionary<7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,115 : INFO : built Dictionary<7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 6 documents (total 60000 corpus positions)
# 2023-04-04 14:30:16,216 : INFO : adding document #0 to Dictionary<7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,231 : INFO : built Dictionary<8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 7 documents (total 70000 corpus positions)
# 2023-04-04 14:30:16,341 : INFO : adding document #0 to Dictionary<8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,359 : INFO : built Dictionary<9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 8 documents (total 80000 corpus positions)
# 2023-04-04 14:30:16,477 : INFO : adding document #0 to Dictionary<9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,498 : INFO : built Dictionary<10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 9 documents (total 90000 corpus positions)
# 2023-04-04 14:30:16,631 : INFO : adding document #0 to Dictionary<10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,653 : INFO : built Dictionary<10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 10 documents (total 100000 corpus positions)
# 2023-04-04 14:30:16,781 : INFO : adding document #0 to Dictionary<10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,808 : INFO : built Dictionary<11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 11 documents (total 110000 corpus positions)
# 2023-04-04 14:30:16,904 : INFO : adding document #0 to Dictionary<11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:16,924 : INFO : built Dictionary<12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 12 documents (total 120000 corpus positions)
# 2023-04-04 14:30:17,046 : INFO : adding document #0 to Dictionary<12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,065 : INFO : built Dictionary<12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 13 documents (total 130000 corpus positions)
# 2023-04-04 14:30:17,168 : INFO : adding document #0 to Dictionary<12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,185 : INFO : built Dictionary<13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 14 documents (total 140000 corpus positions)
# 2023-04-04 14:30:17,291 : INFO : adding document #0 to Dictionary<13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,307 : INFO : built Dictionary<13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 15 documents (total 150000 corpus positions)
# 2023-04-04 14:30:17,419 : INFO : adding document #0 to Dictionary<13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,441 : INFO : built Dictionary<14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 16 documents (total 160000 corpus positions)
# 2023-04-04 14:30:17,558 : INFO : adding document #0 to Dictionary<14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,576 : INFO : built Dictionary<15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 17 documents (total 170000 corpus positions)
# 2023-04-04 14:30:17,690 : INFO : adding document #0 to Dictionary<15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,713 : INFO : built Dictionary<15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 18 documents (total 180000 corpus positions)
# 2023-04-04 14:30:17,845 : INFO : adding document #0 to Dictionary<15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,862 : INFO : built Dictionary<16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 19 documents (total 190000 corpus positions)
# 2023-04-04 14:30:17,962 : INFO : adding document #0 to Dictionary<16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:17,981 : INFO : built Dictionary<16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 20 documents (total 200000 corpus positions)
# 2023-04-04 14:30:18,082 : INFO : adding document #0 to Dictionary<16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,101 : INFO : built Dictionary<17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 21 documents (total 210000 corpus positions)
# 2023-04-04 14:30:18,224 : INFO : adding document #0 to Dictionary<17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,238 : INFO : built Dictionary<18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 22 documents (total 220000 corpus positions)
# 2023-04-04 14:30:18,335 : INFO : adding document #0 to Dictionary<18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,353 : INFO : built Dictionary<18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 23 documents (total 230000 corpus positions)
# 2023-04-04 14:30:18,450 : INFO : adding document #0 to Dictionary<18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,471 : INFO : built Dictionary<19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 24 documents (total 240000 corpus positions)
# 2023-04-04 14:30:18,586 : INFO : adding document #0 to Dictionary<19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,600 : INFO : built Dictionary<19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 25 documents (total 250000 corpus positions)
# 2023-04-04 14:30:18,696 : INFO : adding document #0 to Dictionary<19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,712 : INFO : built Dictionary<20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 26 documents (total 260000 corpus positions)
# 2023-04-04 14:30:18,818 : INFO : adding document #0 to Dictionary<20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,835 : INFO : built Dictionary<20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 27 documents (total 270000 corpus positions)
# 2023-04-04 14:30:18,930 : INFO : adding document #0 to Dictionary<20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:18,949 : INFO : built Dictionary<21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 28 documents (total 280000 corpus positions)
# 2023-04-04 14:30:19,083 : INFO : adding document #0 to Dictionary<21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,103 : INFO : built Dictionary<21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 29 documents (total 290000 corpus positions)
# 2023-04-04 14:30:19,245 : INFO : adding document #0 to Dictionary<21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,271 : INFO : built Dictionary<21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 30 documents (total 300000 corpus positions)
# 2023-04-04 14:30:19,409 : INFO : adding document #0 to Dictionary<21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,423 : INFO : built Dictionary<22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 31 documents (total 310000 corpus positions)
# 2023-04-04 14:30:19,524 : INFO : adding document #0 to Dictionary<22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,540 : INFO : built Dictionary<22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 32 documents (total 320000 corpus positions)
# 2023-04-04 14:30:19,623 : INFO : adding document #0 to Dictionary<22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,636 : INFO : built Dictionary<23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 33 documents (total 330000 corpus positions)
# 2023-04-04 14:30:19,726 : INFO : adding document #0 to Dictionary<23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,734 : INFO : built Dictionary<23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 34 documents (total 340000 corpus positions)
# 2023-04-04 14:30:19,831 : INFO : adding document #0 to Dictionary<23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,843 : INFO : built Dictionary<24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 35 documents (total 350000 corpus positions)
# 2023-04-04 14:30:19,928 : INFO : adding document #0 to Dictionary<24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:19,941 : INFO : built Dictionary<24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 36 documents (total 360000 corpus positions)
# 2023-04-04 14:30:20,020 : INFO : adding document #0 to Dictionary<24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,029 : INFO : built Dictionary<25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 37 documents (total 370000 corpus positions)
# 2023-04-04 14:30:20,125 : INFO : adding document #0 to Dictionary<25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,132 : INFO : built Dictionary<25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 38 documents (total 380000 corpus positions)
# 2023-04-04 14:30:20,213 : INFO : adding document #0 to Dictionary<25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,231 : INFO : built Dictionary<26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 39 documents (total 390000 corpus positions)
# 2023-04-04 14:30:20,316 : INFO : adding document #0 to Dictionary<26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,327 : INFO : built Dictionary<26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 40 documents (total 400000 corpus positions)
# 2023-04-04 14:30:20,402 : INFO : adding document #0 to Dictionary<26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,413 : INFO : built Dictionary<26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 41 documents (total 410000 corpus positions)
# 2023-04-04 14:30:20,491 : INFO : adding document #0 to Dictionary<26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,509 : INFO : built Dictionary<27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 42 documents (total 420000 corpus positions)
# 2023-04-04 14:30:20,581 : INFO : adding document #0 to Dictionary<27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,597 : INFO : built Dictionary<27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 43 documents (total 430000 corpus positions)
# 2023-04-04 14:30:20,680 : INFO : adding document #0 to Dictionary<27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,692 : INFO : built Dictionary<27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 44 documents (total 440000 corpus positions)
# 2023-04-04 14:30:20,773 : INFO : adding document #0 to Dictionary<27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,781 : INFO : built Dictionary<28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 45 documents (total 450000 corpus positions)
# 2023-04-04 14:30:20,863 : INFO : adding document #0 to Dictionary<28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,879 : INFO : built Dictionary<28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 46 documents (total 460000 corpus positions)
# 2023-04-04 14:30:20,958 : INFO : adding document #0 to Dictionary<28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:20,971 : INFO : built Dictionary<28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 47 documents (total 470000 corpus positions)
# 2023-04-04 14:30:21,080 : INFO : adding document #0 to Dictionary<28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,098 : INFO : built Dictionary<29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 48 documents (total 480000 corpus positions)
# 2023-04-04 14:30:21,208 : INFO : adding document #0 to Dictionary<29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,225 : INFO : built Dictionary<29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 49 documents (total 490000 corpus positions)
# 2023-04-04 14:30:21,328 : INFO : adding document #0 to Dictionary<29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,341 : INFO : built Dictionary<29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 50 documents (total 500000 corpus positions)
# 2023-04-04 14:30:21,425 : INFO : adding document #0 to Dictionary<29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,441 : INFO : built Dictionary<30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 51 documents (total 510000 corpus positions)
# 2023-04-04 14:30:21,540 : INFO : adding document #0 to Dictionary<30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,556 : INFO : built Dictionary<30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 52 documents (total 520000 corpus positions)
# 2023-04-04 14:30:21,637 : INFO : adding document #0 to Dictionary<30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,649 : INFO : built Dictionary<31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 53 documents (total 530000 corpus positions)
# 2023-04-04 14:30:21,734 : INFO : adding document #0 to Dictionary<31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,744 : INFO : built Dictionary<31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 54 documents (total 540000 corpus positions)
# 2023-04-04 14:30:21,824 : INFO : adding document #0 to Dictionary<31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,835 : INFO : built Dictionary<32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 55 documents (total 550000 corpus positions)
# 2023-04-04 14:30:21,927 : INFO : adding document #0 to Dictionary<32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:21,943 : INFO : built Dictionary<32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 56 documents (total 560000 corpus positions)
# 2023-04-04 14:30:22,031 : INFO : adding document #0 to Dictionary<32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,045 : INFO : built Dictionary<33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 57 documents (total 570000 corpus positions)
# 2023-04-04 14:30:22,153 : INFO : adding document #0 to Dictionary<33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,170 : INFO : built Dictionary<33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 58 documents (total 580000 corpus positions)
# 2023-04-04 14:30:22,279 : INFO : adding document #0 to Dictionary<33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,295 : INFO : built Dictionary<33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 59 documents (total 590000 corpus positions)
# 2023-04-04 14:30:22,386 : INFO : adding document #0 to Dictionary<33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,402 : INFO : built Dictionary<34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 60 documents (total 600000 corpus positions)
# 2023-04-04 14:30:22,496 : INFO : adding document #0 to Dictionary<34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,511 : INFO : built Dictionary<34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 61 documents (total 610000 corpus positions)
# 2023-04-04 14:30:22,594 : INFO : adding document #0 to Dictionary<34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,608 : INFO : built Dictionary<34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 62 documents (total 620000 corpus positions)
# 2023-04-04 14:30:22,694 : INFO : adding document #0 to Dictionary<34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,710 : INFO : built Dictionary<35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 63 documents (total 630000 corpus positions)
# 2023-04-04 14:30:22,805 : INFO : adding document #0 to Dictionary<35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,821 : INFO : built Dictionary<35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 64 documents (total 640000 corpus positions)
# 2023-04-04 14:30:22,908 : INFO : adding document #0 to Dictionary<35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:22,922 : INFO : built Dictionary<35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 65 documents (total 650000 corpus positions)
# 2023-04-04 14:30:23,018 : INFO : adding document #0 to Dictionary<35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,029 : INFO : built Dictionary<36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 66 documents (total 660000 corpus positions)
# 2023-04-04 14:30:23,123 : INFO : adding document #0 to Dictionary<36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,137 : INFO : built Dictionary<36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 67 documents (total 670000 corpus positions)
# 2023-04-04 14:30:23,317 : INFO : adding document #0 to Dictionary<36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,342 : INFO : built Dictionary<36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 68 documents (total 680000 corpus positions)
# 2023-04-04 14:30:23,462 : INFO : adding document #0 to Dictionary<36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,484 : INFO : built Dictionary<37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 69 documents (total 690000 corpus positions)
# 2023-04-04 14:30:23,654 : INFO : adding document #0 to Dictionary<37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,673 : INFO : built Dictionary<37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 70 documents (total 700000 corpus positions)
# 2023-04-04 14:30:23,780 : INFO : adding document #0 to Dictionary<37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,795 : INFO : built Dictionary<37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 71 documents (total 710000 corpus positions)
# 2023-04-04 14:30:23,888 : INFO : adding document #0 to Dictionary<37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:23,900 : INFO : built Dictionary<37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 72 documents (total 720000 corpus positions)
# 2023-04-04 14:30:23,999 : INFO : adding document #0 to Dictionary<37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,017 : INFO : built Dictionary<38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 73 documents (total 730000 corpus positions)
# 2023-04-04 14:30:24,112 : INFO : adding document #0 to Dictionary<38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,125 : INFO : built Dictionary<38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 74 documents (total 740000 corpus positions)
# 2023-04-04 14:30:24,225 : INFO : adding document #0 to Dictionary<38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,239 : INFO : built Dictionary<39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 75 documents (total 750000 corpus positions)
# 2023-04-04 14:30:24,340 : INFO : adding document #0 to Dictionary<39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,354 : INFO : built Dictionary<39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 76 documents (total 760000 corpus positions)
# 2023-04-04 14:30:24,445 : INFO : adding document #0 to Dictionary<39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,467 : INFO : built Dictionary<39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 77 documents (total 770000 corpus positions)
# 2023-04-04 14:30:24,555 : INFO : adding document #0 to Dictionary<39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,569 : INFO : built Dictionary<40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 78 documents (total 780000 corpus positions)
# 2023-04-04 14:30:24,658 : INFO : adding document #0 to Dictionary<40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,668 : INFO : built Dictionary<40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 79 documents (total 790000 corpus positions)
# 2023-04-04 14:30:24,749 : INFO : adding document #0 to Dictionary<40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,763 : INFO : built Dictionary<40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 80 documents (total 800000 corpus positions)
# 2023-04-04 14:30:24,852 : INFO : adding document #0 to Dictionary<40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:24,873 : INFO : built Dictionary<41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 81 documents (total 810000 corpus positions)
# 2023-04-04 14:30:25,127 : INFO : adding document #0 to Dictionary<41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,152 : INFO : built Dictionary<41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 82 documents (total 820000 corpus positions)
# 2023-04-04 14:30:25,257 : INFO : adding document #0 to Dictionary<41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,275 : INFO : built Dictionary<41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 83 documents (total 830000 corpus positions)
# 2023-04-04 14:30:25,357 : INFO : adding document #0 to Dictionary<41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,380 : INFO : built Dictionary<42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 84 documents (total 840000 corpus positions)
# 2023-04-04 14:30:25,468 : INFO : adding document #0 to Dictionary<42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,483 : INFO : built Dictionary<42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 85 documents (total 850000 corpus positions)
# 2023-04-04 14:30:25,585 : INFO : adding document #0 to Dictionary<42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,600 : INFO : built Dictionary<42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 86 documents (total 860000 corpus positions)
# 2023-04-04 14:30:25,682 : INFO : adding document #0 to Dictionary<42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,696 : INFO : built Dictionary<43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 87 documents (total 870000 corpus positions)
# 2023-04-04 14:30:25,781 : INFO : adding document #0 to Dictionary<43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,792 : INFO : built Dictionary<43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 88 documents (total 880000 corpus positions)
# 2023-04-04 14:30:25,871 : INFO : adding document #0 to Dictionary<43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:25,889 : INFO : built Dictionary<43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 89 documents (total 890000 corpus positions)
# 2023-04-04 14:30:25,992 : INFO : adding document #0 to Dictionary<43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,015 : INFO : built Dictionary<44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 90 documents (total 900000 corpus positions)
# 2023-04-04 14:30:26,119 : INFO : adding document #0 to Dictionary<44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,137 : INFO : built Dictionary<44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 91 documents (total 910000 corpus positions)
# 2023-04-04 14:30:26,237 : INFO : adding document #0 to Dictionary<44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,251 : INFO : built Dictionary<44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 92 documents (total 920000 corpus positions)
# 2023-04-04 14:30:26,350 : INFO : adding document #0 to Dictionary<44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,364 : INFO : built Dictionary<45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 93 documents (total 930000 corpus positions)
# 2023-04-04 14:30:26,442 : INFO : adding document #0 to Dictionary<45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,452 : INFO : built Dictionary<45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 94 documents (total 940000 corpus positions)
# 2023-04-04 14:30:26,528 : INFO : adding document #0 to Dictionary<45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,537 : INFO : built Dictionary<45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 95 documents (total 950000 corpus positions)
# 2023-04-04 14:30:26,609 : INFO : adding document #0 to Dictionary<45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,632 : INFO : built Dictionary<46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 96 documents (total 960000 corpus positions)
# 2023-04-04 14:30:26,704 : INFO : adding document #0 to Dictionary<46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,721 : INFO : built Dictionary<46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 97 documents (total 970000 corpus positions)
# 2023-04-04 14:30:26,885 : INFO : adding document #0 to Dictionary<46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:26,905 : INFO : built Dictionary<46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 98 documents (total 980000 corpus positions)
# 2023-04-04 14:30:26,997 : INFO : adding document #0 to Dictionary<46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,012 : INFO : built Dictionary<47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 99 documents (total 990000 corpus positions)
# 2023-04-04 14:30:27,090 : INFO : adding document #0 to Dictionary<47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,104 : INFO : built Dictionary<47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 100 documents (total 1000000 corpus positions)
# 2023-04-04 14:30:27,175 : INFO : adding document #0 to Dictionary<47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,185 : INFO : built Dictionary<47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 101 documents (total 1010000 corpus positions)
# 2023-04-04 14:30:27,262 : INFO : adding document #0 to Dictionary<47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,272 : INFO : built Dictionary<48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 102 documents (total 1020000 corpus positions)
# 2023-04-04 14:30:27,346 : INFO : adding document #0 to Dictionary<48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,357 : INFO : built Dictionary<48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 103 documents (total 1030000 corpus positions)
# 2023-04-04 14:30:27,437 : INFO : adding document #0 to Dictionary<48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,452 : INFO : built Dictionary<48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 104 documents (total 1040000 corpus positions)
# 2023-04-04 14:30:27,531 : INFO : adding document #0 to Dictionary<48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,540 : INFO : built Dictionary<49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 105 documents (total 1050000 corpus positions)
# 2023-04-04 14:30:27,619 : INFO : adding document #0 to Dictionary<49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,635 : INFO : built Dictionary<49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 106 documents (total 1060000 corpus positions)
# 2023-04-04 14:30:27,723 : INFO : adding document #0 to Dictionary<49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,734 : INFO : built Dictionary<49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 107 documents (total 1070000 corpus positions)
# 2023-04-04 14:30:27,811 : INFO : adding document #0 to Dictionary<49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,823 : INFO : built Dictionary<50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 108 documents (total 1080000 corpus positions)
# 2023-04-04 14:30:27,898 : INFO : adding document #0 to Dictionary<50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:27,911 : INFO : built Dictionary<50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 109 documents (total 1090000 corpus positions)
# 2023-04-04 14:30:27,993 : INFO : adding document #0 to Dictionary<50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,001 : INFO : built Dictionary<50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 110 documents (total 1100000 corpus positions)
# 2023-04-04 14:30:28,069 : INFO : adding document #0 to Dictionary<50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,088 : INFO : built Dictionary<51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 111 documents (total 1110000 corpus positions)
# 2023-04-04 14:30:28,159 : INFO : adding document #0 to Dictionary<51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,174 : INFO : built Dictionary<51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 112 documents (total 1120000 corpus positions)
# 2023-04-04 14:30:28,246 : INFO : adding document #0 to Dictionary<51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,256 : INFO : built Dictionary<51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 113 documents (total 1130000 corpus positions)
# 2023-04-04 14:30:28,331 : INFO : adding document #0 to Dictionary<51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,339 : INFO : built Dictionary<51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 114 documents (total 1140000 corpus positions)
# 2023-04-04 14:30:28,414 : INFO : adding document #0 to Dictionary<51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,423 : INFO : built Dictionary<52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 115 documents (total 1150000 corpus positions)
# 2023-04-04 14:30:28,503 : INFO : adding document #0 to Dictionary<52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,519 : INFO : built Dictionary<52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 116 documents (total 1160000 corpus positions)
# 2023-04-04 14:30:28,596 : INFO : adding document #0 to Dictionary<52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,608 : INFO : built Dictionary<52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 117 documents (total 1170000 corpus positions)
# 2023-04-04 14:30:28,696 : INFO : adding document #0 to Dictionary<52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,711 : INFO : built Dictionary<52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 118 documents (total 1180000 corpus positions)
# 2023-04-04 14:30:28,785 : INFO : adding document #0 to Dictionary<52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,800 : INFO : built Dictionary<53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 119 documents (total 1190000 corpus positions)
# 2023-04-04 14:30:28,877 : INFO : adding document #0 to Dictionary<53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,886 : INFO : built Dictionary<53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 120 documents (total 1200000 corpus positions)
# 2023-04-04 14:30:28,966 : INFO : adding document #0 to Dictionary<53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:28,980 : INFO : built Dictionary<53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 121 documents (total 1210000 corpus positions)
# 2023-04-04 14:30:29,059 : INFO : adding document #0 to Dictionary<53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,072 : INFO : built Dictionary<53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 122 documents (total 1220000 corpus positions)
# 2023-04-04 14:30:29,150 : INFO : adding document #0 to Dictionary<53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,163 : INFO : built Dictionary<54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 123 documents (total 1230000 corpus positions)
# 2023-04-04 14:30:29,322 : INFO : adding document #0 to Dictionary<54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,344 : INFO : built Dictionary<54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 124 documents (total 1240000 corpus positions)
# 2023-04-04 14:30:29,429 : INFO : adding document #0 to Dictionary<54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,442 : INFO : built Dictionary<54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 125 documents (total 1250000 corpus positions)
# 2023-04-04 14:30:29,521 : INFO : adding document #0 to Dictionary<54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,531 : INFO : built Dictionary<54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 126 documents (total 1260000 corpus positions)
# 2023-04-04 14:30:29,610 : INFO : adding document #0 to Dictionary<54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,621 : INFO : built Dictionary<55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 127 documents (total 1270000 corpus positions)
# 2023-04-04 14:30:29,701 : INFO : adding document #0 to Dictionary<55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,713 : INFO : built Dictionary<55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 128 documents (total 1280000 corpus positions)
# 2023-04-04 14:30:29,798 : INFO : adding document #0 to Dictionary<55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,806 : INFO : built Dictionary<55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 129 documents (total 1290000 corpus positions)
# 2023-04-04 14:30:29,898 : INFO : adding document #0 to Dictionary<55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:29,914 : INFO : built Dictionary<55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 130 documents (total 1300000 corpus positions)
# 2023-04-04 14:30:30,015 : INFO : adding document #0 to Dictionary<55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,031 : INFO : built Dictionary<55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 131 documents (total 1310000 corpus positions)
# 2023-04-04 14:30:30,129 : INFO : adding document #0 to Dictionary<55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,144 : INFO : built Dictionary<55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 132 documents (total 1320000 corpus positions)
# 2023-04-04 14:30:30,250 : INFO : adding document #0 to Dictionary<55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,265 : INFO : built Dictionary<56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 133 documents (total 1330000 corpus positions)
# 2023-04-04 14:30:30,375 : INFO : adding document #0 to Dictionary<56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,389 : INFO : built Dictionary<56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 134 documents (total 1340000 corpus positions)
# 2023-04-04 14:30:30,492 : INFO : adding document #0 to Dictionary<56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,509 : INFO : built Dictionary<56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 135 documents (total 1350000 corpus positions)
# 2023-04-04 14:30:30,599 : INFO : adding document #0 to Dictionary<56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,617 : INFO : built Dictionary<56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 136 documents (total 1360000 corpus positions)
# 2023-04-04 14:30:30,721 : INFO : adding document #0 to Dictionary<56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,736 : INFO : built Dictionary<56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 137 documents (total 1370000 corpus positions)
# 2023-04-04 14:30:30,831 : INFO : adding document #0 to Dictionary<56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,846 : INFO : built Dictionary<56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 138 documents (total 1380000 corpus positions)
# 2023-04-04 14:30:30,948 : INFO : adding document #0 to Dictionary<56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:30,962 : INFO : built Dictionary<57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 139 documents (total 1390000 corpus positions)
# 2023-04-04 14:30:31,068 : INFO : adding document #0 to Dictionary<57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,084 : INFO : built Dictionary<57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 140 documents (total 1400000 corpus positions)
# 2023-04-04 14:30:31,186 : INFO : adding document #0 to Dictionary<57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,201 : INFO : built Dictionary<57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 141 documents (total 1410000 corpus positions)
# 2023-04-04 14:30:31,314 : INFO : adding document #0 to Dictionary<57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,335 : INFO : built Dictionary<57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 142 documents (total 1420000 corpus positions)
# 2023-04-04 14:30:31,428 : INFO : adding document #0 to Dictionary<57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,443 : INFO : built Dictionary<58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 143 documents (total 1430000 corpus positions)
# 2023-04-04 14:30:31,544 : INFO : adding document #0 to Dictionary<58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,559 : INFO : built Dictionary<58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 144 documents (total 1440000 corpus positions)
# 2023-04-04 14:30:31,667 : INFO : adding document #0 to Dictionary<58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,691 : INFO : built Dictionary<58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 145 documents (total 1450000 corpus positions)
# 2023-04-04 14:30:31,863 : INFO : adding document #0 to Dictionary<58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,886 : INFO : built Dictionary<58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 146 documents (total 1460000 corpus positions)
# 2023-04-04 14:30:31,982 : INFO : adding document #0 to Dictionary<58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:31,999 : INFO : built Dictionary<58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 147 documents (total 1470000 corpus positions)
# 2023-04-04 14:30:32,098 : INFO : adding document #0 to Dictionary<58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,114 : INFO : built Dictionary<59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 148 documents (total 1480000 corpus positions)
# 2023-04-04 14:30:32,208 : INFO : adding document #0 to Dictionary<59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,219 : INFO : built Dictionary<59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 149 documents (total 1490000 corpus positions)
# 2023-04-04 14:30:32,325 : INFO : adding document #0 to Dictionary<59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,342 : INFO : built Dictionary<59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 150 documents (total 1500000 corpus positions)
# 2023-04-04 14:30:32,436 : INFO : adding document #0 to Dictionary<59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,454 : INFO : built Dictionary<59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 151 documents (total 1510000 corpus positions)
# 2023-04-04 14:30:32,564 : INFO : adding document #0 to Dictionary<59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,583 : INFO : built Dictionary<60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 152 documents (total 1520000 corpus positions)
# 2023-04-04 14:30:32,676 : INFO : adding document #0 to Dictionary<60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,699 : INFO : built Dictionary<60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 153 documents (total 1530000 corpus positions)
# 2023-04-04 14:30:32,803 : INFO : adding document #0 to Dictionary<60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:30:32,818 : INFO : built Dictionary<60490 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 154 documents (total 1540000 corpus positions)
# 2023-04-04 14:30:32,915 : INFO : adding document #0 to Dictionary<60490 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# ...
# 2023-04-04 14:33:29,570 : INFO : adding document #0 to Dictionary<234598 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:29,587 : INFO : built Dictionary<234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1653 documents (total 16530000 corpus positions)
# 2023-04-04 14:33:29,674 : INFO : adding document #0 to Dictionary<234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:29,703 : INFO : built Dictionary<234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1654 documents (total 16540000 corpus positions)
# 2023-04-04 14:33:29,789 : INFO : adding document #0 to Dictionary<234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:29,803 : INFO : built Dictionary<234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1655 documents (total 16550000 corpus positions)
# 2023-04-04 14:33:29,884 : INFO : adding document #0 to Dictionary<234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:29,900 : INFO : built Dictionary<234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1656 documents (total 16560000 corpus positions)
# 2023-04-04 14:33:29,998 : INFO : adding document #0 to Dictionary<234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,014 : INFO : built Dictionary<235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1657 documents (total 16570000 corpus positions)
# 2023-04-04 14:33:30,099 : INFO : adding document #0 to Dictionary<235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,113 : INFO : built Dictionary<235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1658 documents (total 16580000 corpus positions)
# 2023-04-04 14:33:30,354 : INFO : adding document #0 to Dictionary<235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,388 : INFO : built Dictionary<235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1659 documents (total 16590000 corpus positions)
# 2023-04-04 14:33:30,526 : INFO : adding document #0 to Dictionary<235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,541 : INFO : built Dictionary<235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1660 documents (total 16600000 corpus positions)
# 2023-04-04 14:33:30,623 : INFO : adding document #0 to Dictionary<235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,632 : INFO : built Dictionary<235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1661 documents (total 16610000 corpus positions)
# 2023-04-04 14:33:30,730 : INFO : adding document #0 to Dictionary<235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,750 : INFO : built Dictionary<235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1662 documents (total 16620000 corpus positions)
# 2023-04-04 14:33:30,842 : INFO : adding document #0 to Dictionary<235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,857 : INFO : built Dictionary<235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1663 documents (total 16630000 corpus positions)
# 2023-04-04 14:33:30,934 : INFO : adding document #0 to Dictionary<235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:30,946 : INFO : built Dictionary<235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1664 documents (total 16640000 corpus positions)
# 2023-04-04 14:33:31,032 : INFO : adding document #0 to Dictionary<235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,048 : INFO : built Dictionary<235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1665 documents (total 16650000 corpus positions)
# 2023-04-04 14:33:31,147 : INFO : adding document #0 to Dictionary<235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,164 : INFO : built Dictionary<235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1666 documents (total 16660000 corpus positions)
# 2023-04-04 14:33:31,262 : INFO : adding document #0 to Dictionary<235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,278 : INFO : built Dictionary<235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1667 documents (total 16670000 corpus positions)
# 2023-04-04 14:33:31,376 : INFO : adding document #0 to Dictionary<235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,393 : INFO : built Dictionary<235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1668 documents (total 16680000 corpus positions)
# 2023-04-04 14:33:31,482 : INFO : adding document #0 to Dictionary<235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,498 : INFO : built Dictionary<236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1669 documents (total 16690000 corpus positions)
# 2023-04-04 14:33:31,567 : INFO : adding document #0 to Dictionary<236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,585 : INFO : built Dictionary<236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1670 documents (total 16700000 corpus positions)
# 2023-04-04 14:33:31,663 : INFO : adding document #0 to Dictionary<236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,676 : INFO : built Dictionary<236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1671 documents (total 16710000 corpus positions)
# 2023-04-04 14:33:31,748 : INFO : adding document #0 to Dictionary<236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,763 : INFO : built Dictionary<236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1672 documents (total 16720000 corpus positions)
# 2023-04-04 14:33:31,820 : INFO : adding document #0 to Dictionary<236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,831 : INFO : built Dictionary<236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1673 documents (total 16730000 corpus positions)
# 2023-04-04 14:33:31,886 : INFO : adding document #0 to Dictionary<236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,896 : INFO : built Dictionary<236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1674 documents (total 16740000 corpus positions)
# 2023-04-04 14:33:31,956 : INFO : adding document #0 to Dictionary<236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:31,966 : INFO : built Dictionary<236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1675 documents (total 16750000 corpus positions)
# 2023-04-04 14:33:32,049 : INFO : adding document #0 to Dictionary<236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,063 : INFO : built Dictionary<236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1676 documents (total 16760000 corpus positions)
# 2023-04-04 14:33:32,131 : INFO : adding document #0 to Dictionary<236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,146 : INFO : built Dictionary<236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1677 documents (total 16770000 corpus positions)
# 2023-04-04 14:33:32,214 : INFO : adding document #0 to Dictionary<236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,227 : INFO : built Dictionary<237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1678 documents (total 16780000 corpus positions)
# 2023-04-04 14:33:32,293 : INFO : adding document #0 to Dictionary<237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,304 : INFO : built Dictionary<237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1679 documents (total 16790000 corpus positions)
# 2023-04-04 14:33:32,362 : INFO : adding document #0 to Dictionary<237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,375 : INFO : built Dictionary<237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1680 documents (total 16800000 corpus positions)
# 2023-04-04 14:33:32,438 : INFO : adding document #0 to Dictionary<237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,447 : INFO : built Dictionary<237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1681 documents (total 16810000 corpus positions)
# 2023-04-04 14:33:32,524 : INFO : adding document #0 to Dictionary<237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,537 : INFO : built Dictionary<237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1682 documents (total 16820000 corpus positions)
# 2023-04-04 14:33:32,605 : INFO : adding document #0 to Dictionary<237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,620 : INFO : built Dictionary<237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1683 documents (total 16830000 corpus positions)
# 2023-04-04 14:33:32,679 : INFO : adding document #0 to Dictionary<237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,693 : INFO : built Dictionary<237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1684 documents (total 16840000 corpus positions)
# 2023-04-04 14:33:32,758 : INFO : adding document #0 to Dictionary<237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,771 : INFO : built Dictionary<237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1685 documents (total 16850000 corpus positions)
# 2023-04-04 14:33:32,829 : INFO : adding document #0 to Dictionary<237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,841 : INFO : built Dictionary<237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1686 documents (total 16860000 corpus positions)
# 2023-04-04 14:33:32,898 : INFO : adding document #0 to Dictionary<237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,910 : INFO : built Dictionary<237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1687 documents (total 16870000 corpus positions)
# 2023-04-04 14:33:32,965 : INFO : adding document #0 to Dictionary<237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:32,977 : INFO : built Dictionary<237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1688 documents (total 16880000 corpus positions)
# 2023-04-04 14:33:33,182 : INFO : adding document #0 to Dictionary<237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,206 : INFO : built Dictionary<237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1689 documents (total 16890000 corpus positions)
# 2023-04-04 14:33:33,321 : INFO : adding document #0 to Dictionary<237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,333 : INFO : built Dictionary<237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1690 documents (total 16900000 corpus positions)
# 2023-04-04 14:33:33,410 : INFO : adding document #0 to Dictionary<237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,423 : INFO : built Dictionary<237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1691 documents (total 16910000 corpus positions)
# 2023-04-04 14:33:33,486 : INFO : adding document #0 to Dictionary<237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,496 : INFO : built Dictionary<237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1692 documents (total 16920000 corpus positions)
# 2023-04-04 14:33:33,583 : INFO : adding document #0 to Dictionary<237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,598 : INFO : built Dictionary<238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1693 documents (total 16930000 corpus positions)
# 2023-04-04 14:33:33,667 : INFO : adding document #0 to Dictionary<238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,680 : INFO : built Dictionary<238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1694 documents (total 16940000 corpus positions)
# 2023-04-04 14:33:33,742 : INFO : adding document #0 to Dictionary<238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,757 : INFO : built Dictionary<238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1695 documents (total 16950000 corpus positions)
# 2023-04-04 14:33:33,829 : INFO : adding document #0 to Dictionary<238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,841 : INFO : built Dictionary<238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1696 documents (total 16960000 corpus positions)
# 2023-04-04 14:33:33,913 : INFO : adding document #0 to Dictionary<238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:33,927 : INFO : built Dictionary<238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1697 documents (total 16970000 corpus positions)
# 2023-04-04 14:33:33,994 : INFO : adding document #0 to Dictionary<238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:34,018 : INFO : built Dictionary<238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1698 documents (total 16980000 corpus positions)
# 2023-04-04 14:33:34,100 : INFO : adding document #0 to Dictionary<238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:34,111 : INFO : built Dictionary<238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1699 documents (total 16990000 corpus positions)
# 2023-04-04 14:33:34,180 : INFO : adding document #0 to Dictionary<238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:34,196 : INFO : built Dictionary<238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1700 documents (total 17000000 corpus positions)
# 2023-04-04 14:33:34,243 : INFO : adding document #0 to Dictionary<238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2023-04-04 14:33:34,254 : INFO : built Dictionary<238542 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1701 documents (total 17005207 corpus positions)
# 2023-04-04 14:33:34,643 : INFO : discarding 218466 tokens: [('a', 1701), ('ability', 934), ('able', 1202), ('about', 1687), ('above', 1327), ('abstention', 13), ('accepted', 945), ('according', 1468), ('account', 1113), ('act', 1312)]...
# 2023-04-04 14:33:34,644 : INFO : keeping 20076 tokens which were in no less than 20 and no more than 850 (=50.0%) documents
# 2023-04-04 14:33:34,756 : INFO : resulting dictionary: Dictionary<20076 unique tokens: ['abacus', 'abnormal', 'abolished', 'abolition', 'absence']...>

# %% [markdown]
# # Training

# %%
from gensim.models import LdaModel
topic_model_class = LdaModel

ensemble_workers = 4
num_models = 8

distance_workers = 4

num_topics = 20
passes = 2

from gensim.models import EnsembleLda
ensemble = EnsembleLda(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    passes=passes,
    num_models=num_models,
    topic_model_class=LdaModel,
    ensemble_workers=ensemble_workers,
    distance_workers=distance_workers
)

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
# Out:
# 2023-04-04 14:33:53,239 : INFO : generating 8 topic models using 4 workers
# 2023-04-04 14:44:16,722 : INFO : generating a 160 x 160 asymmetric distance matrix...
# 2023-04-04 14:44:28,490 : INFO : fitting the clustering model, using 4 for min_samples
# 2023-04-04 14:44:28,569 : INFO : generating stable topics, using 3 for min_cores
# 2023-04-04 14:44:28,569 : INFO : found 2 clusters
# 2023-04-04 14:44:28,600 : INFO : found 1 stable topics
# 2023-04-04 14:44:28,616 : INFO : generating classic gensim model representation based on results from the ensemble
# 2023-04-04 14:44:28,914 : INFO : using symmetric alpha at 1.0
# 2023-04-04 14:44:28,914 : INFO : using symmetric eta at 1.0
# 2023-04-04 14:44:28,914 : INFO : using serial LDA version on this node
# 2023-04-04 14:44:28,914 : INFO : running online (multi-pass) LDA training, 1 topics, 0 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-04-04 14:44:28,914 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2023-04-04 14:44:28,929 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=1, decay=0.5, chunksize=2000> in 0.02s', 'datetime': '2023-04-04T14:44:28.929910', 'gensim': '4.3.1', 'python': '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 160
# 1

# %% [markdown]
# # Tuning

# %%
import numpy as np
shape = ensemble.asymmetric_distance_matrix.shape
without_diagonal = ensemble.asymmetric_distance_matrix[~np.eye(shape[0], dtype=bool)].reshape(shape[0], -1)
print(without_diagonal.min(), without_diagonal.mean(), without_diagonal.max())

ensemble.recluster(eps=0.09, min_samples=2, min_cores=2)

print(len(ensemble.get_topics()))
# Out:
# 2023-04-04 14:44:29,055 : INFO : fitting the clustering model
# 0.00652840948496336 0.037036847551971244 0.14483295280732034
# 2023-04-04 14:44:29,134 : INFO : generating stable topics
# 2023-04-04 14:44:29,134 : INFO : found 4 clusters
# 2023-04-04 14:44:29,181 : INFO : found 1 stable topics
# 2023-04-04 14:44:29,181 : INFO : generating classic gensim model representation based on results from the ensemble
# 2023-04-04 14:44:29,181 : INFO : using symmetric alpha at 1.0
# 2023-04-04 14:44:29,181 : INFO : using symmetric eta at 1.0
# 2023-04-04 14:44:29,196 : INFO : using serial LDA version on this node
# 2023-04-04 14:44:29,212 : INFO : running online (multi-pass) LDA training, 1 topics, 0 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-04-04 14:44:29,212 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2023-04-04 14:44:29,212 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=1, decay=0.5, chunksize=2000> in 0.00s', 'datetime': '2023-04-04T14:44:29.212611', 'gensim': '4.3.1', 'python': '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 1

# %% [markdown]
# # Increasing the Size

# %%
from gensim.models import LdaMulticore

model1 = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=9,
    passes=4,
)

model2 = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=11,
    passes=2,
)

# add_model supports various types of input, check out its docstring
ensemble.add_model(model1)
ensemble.add_model(model2)

ensemble.recluster()

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
# Out:
# 2023-04-04 14:44:29,416 : INFO : using symmetric alpha at 0.1111111111111111
# 2023-04-04 14:44:29,416 : INFO : using symmetric eta at 0.1111111111111111
# 2023-04-04 14:44:29,432 : INFO : using serial LDA version on this node
# 2023-04-04 14:44:29,479 : INFO : running online LDA training, 9 topics, 4 passes over the supplied corpus of 1701 documents, updating every 14000 documents, evaluating every ~1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-04-04 14:44:29,479 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2023-04-04 14:44:29,479 : INFO : training LDA model using 7 processes
# 2023-04-04 14:44:44,092 : INFO : PROGRESS: pass 0, dispatched chunk #0 = documents up to #1701/1701, outstanding queue size 1
# 2023-04-04 14:45:00,493 : INFO : topic #0 (0.111): 0.036*"as" + 0.002*"km" + 0.001*"soviet" + 0.001*"jewish" + 0.001*"energy" + 0.001*"bc" + 0.001*"band" + 0.001*"india" + 0.001*"japanese" + 0.001*"russian"
# 2023-04-04 14:45:00,498 : INFO : topic #2 (0.111): 0.033*"as" + 0.001*"irish" + 0.001*"km" + 0.001*"emperor" + 0.001*"software" + 0.001*"italian" + 0.001*"band" + 0.001*"prime" + 0.001*"minister" + 0.001*"y"
# 2023-04-04 14:45:00,503 : INFO : topic #7 (0.111): 0.036*"as" + 0.001*"software" + 0.001*"chinese" + 0.001*"km" + 0.001*"league" + 0.001*"china" + 0.001*"economy" + 0.001*"actor" + 0.001*"bc" + 0.001*"energy"
# 2023-04-04 14:45:00,507 : INFO : topic #6 (0.111): 0.031*"as" + 0.001*"japan" + 0.001*"chinese" + 0.001*"soviet" + 0.001*"japanese" + 0.001*"y" + 0.001*"china" + 0.001*"band" + 0.001*"jewish" + 0.001*"minister"
# 2023-04-04 14:45:00,509 : INFO : topic #4 (0.111): 0.027*"as" + 0.001*"soviet" + 0.001*"china" + 0.001*"league" + 0.001*"y" + 0.001*"parliament" + 0.001*"software" + 0.001*"km" + 0.001*"season" + 0.001*"prime"
# 2023-04-04 14:45:00,512 : INFO : topic diff=1.028107, rho=1.000000
# 2023-04-04 14:45:31,264 : INFO : -9.134 per-word bound, 561.8 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:45:31,266 : INFO : PROGRESS: pass 1, dispatched chunk #0 = documents up to #1701/1701, outstanding queue size 1
# 2023-04-04 14:45:47,138 : INFO : topic #1 (0.111): 0.026*"as" + 0.002*"actor" + 0.002*"apple" + 0.002*"jewish" + 0.001*"software" + 0.001*"lake" + 0.001*"actress" + 0.001*"minister" + 0.001*"mac" + 0.001*"import"
# 2023-04-04 14:45:47,141 : INFO : topic #5 (0.111): 0.029*"as" + 0.001*"love" + 0.001*"bc" + 0.001*"russian" + 0.001*"league" + 0.001*"soviet" + 0.001*"season" + 0.001*"carbon" + 0.001*"album" + 0.001*"alexander"
# 2023-04-04 14:45:47,143 : INFO : topic #2 (0.111): 0.034*"as" + 0.001*"irish" + 0.001*"emperor" + 0.001*"y" + 0.001*"band" + 0.001*"italian" + 0.001*"metal" + 0.001*"km" + 0.001*"philosophy" + 0.001*"software"
# 2023-04-04 14:45:47,146 : INFO : topic #4 (0.111): 0.027*"as" + 0.001*"soviet" + 0.001*"y" + 0.001*"fiction" + 0.001*"china" + 0.001*"love" + 0.001*"league" + 0.001*"parliament" + 0.001*"season" + 0.001*"novel"
# 2023-04-04 14:45:47,149 : INFO : topic #3 (0.111): 0.029*"as" + 0.002*"est" + 0.002*"km" + 0.001*"minister" + 0.001*"soviet" + 0.001*"economy" + 0.001*"emperor" + 0.001*"prime" + 0.001*"parliament" + 0.001*"spanish"
# 2023-04-04 14:45:47,151 : INFO : topic diff=0.156337, rho=0.592297
# 2023-04-04 14:46:19,309 : INFO : -9.067 per-word bound, 536.5 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:46:19,312 : INFO : PROGRESS: pass 2, dispatched chunk #0 = documents up to #1701/1701, outstanding queue size 1
# 2023-04-04 14:46:35,336 : INFO : topic #5 (0.111): 0.029*"as" + 0.002*"love" + 0.001*"moon" + 0.001*"apollo" + 0.001*"carbon" + 0.001*"season" + 0.001*"alexander" + 0.001*"bc" + 0.001*"memory" + 0.001*"album"
# 2023-04-04 14:46:35,339 : INFO : topic #3 (0.111): 0.028*"as" + 0.003*"est" + 0.003*"km" + 0.002*"economy" + 0.002*"minister" + 0.002*"soviet" + 0.002*"parliament" + 0.002*"constitution" + 0.002*"elected" + 0.002*"prime"
# 2023-04-04 14:46:35,344 : INFO : topic #2 (0.111): 0.034*"as" + 0.002*"irish" + 0.001*"y" + 0.001*"emperor" + 0.001*"band" + 0.001*"metal" + 0.001*"philosophy" + 0.001*"frac" + 0.001*"bass" + 0.001*"italian"
# 2023-04-04 14:46:35,348 : INFO : topic #1 (0.111): 0.025*"as" + 0.003*"actor" + 0.002*"jewish" + 0.002*"actress" + 0.002*"apple" + 0.002*"singer" + 0.001*"prize" + 0.001*"composer" + 0.001*"software" + 0.001*"canadian"
# 2023-04-04 14:46:35,350 : INFO : topic #7 (0.111): 0.036*"as" + 0.003*"chinese" + 0.002*"software" + 0.002*"china" + 0.001*"microsoft" + 0.001*"california" + 0.001*"india" + 0.001*"km" + 0.001*"economy" + 0.001*"lebanon"
# 2023-04-04 14:46:35,353 : INFO : topic diff=0.191013, rho=0.509614
# 2023-04-04 14:47:08,712 : INFO : -9.005 per-word bound, 513.8 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:47:08,713 : INFO : PROGRESS: pass 3, dispatched chunk #0 = documents up to #1701/1701, outstanding queue size 1
# 2023-04-04 14:47:24,324 : INFO : topic #8 (0.111): 0.026*"as" + 0.005*"league" + 0.003*"ball" + 0.002*"baseball" + 0.002*"football" + 0.002*"season" + 0.002*"club" + 0.002*"lincoln" + 0.002*"kong" + 0.001*"flag"
# 2023-04-04 14:47:24,327 : INFO : topic #1 (0.111): 0.025*"as" + 0.004*"actor" + 0.002*"actress" + 0.002*"jewish" + 0.002*"singer" + 0.002*"apple" + 0.002*"prize" + 0.002*"composer" + 0.001*"nobel" + 0.001*"canadian"
# 2023-04-04 14:47:24,329 : INFO : topic #0 (0.111): 0.037*"as" + 0.002*"energy" + 0.001*"aircraft" + 0.001*"cell" + 0.001*"soviet" + 0.001*"scientific" + 0.001*"india" + 0.001*"color" + 0.001*"km" + 0.001*"mind"
# 2023-04-04 14:47:24,331 : INFO : topic #3 (0.111): 0.027*"as" + 0.004*"est" + 0.003*"km" + 0.002*"economy" + 0.002*"minister" + 0.002*"soviet" + 0.002*"parliament" + 0.002*"constitution" + 0.002*"elected" + 0.002*"prime"
# 2023-04-04 14:47:24,333 : INFO : topic #5 (0.111): 0.029*"as" + 0.002*"love" + 0.001*"apollo" + 0.001*"moon" + 0.001*"season" + 0.001*"carbon" + 0.001*"memory" + 0.001*"alexander" + 0.001*"bit" + 0.001*"digital"
# 2023-04-04 14:47:24,337 : INFO : topic diff=0.165281, rho=0.454053
# 2023-04-04 14:47:56,136 : INFO : -8.970 per-word bound, 501.5 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:47:56,213 : INFO : LdaMulticore lifecycle event {'msg': 'trained LdaMulticore<num_terms=20076, num_topics=9, decay=0.5, chunksize=2000> in 206.73s', 'datetime': '2023-04-04T14:47:56.213590', 'gensim': '4.3.1', 'python': '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2023-04-04 14:47:56,220 : INFO : using symmetric alpha at 0.09090909090909091
# 2023-04-04 14:47:56,223 : INFO : using symmetric eta at 0.09090909090909091
# 2023-04-04 14:47:56,238 : INFO : using serial LDA version on this node
# 2023-04-04 14:47:56,310 : INFO : running online (multi-pass) LDA training, 11 topics, 2 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-04-04 14:47:56,312 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2023-04-04 14:48:30,387 : INFO : -10.505 per-word bound, 1453.7 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:48:30,389 : INFO : PROGRESS: pass 0, at document #1701/1701
# 2023-04-04 14:48:44,797 : INFO : topic #8 (0.091): 0.034*"as" + 0.001*"km" + 0.001*"league" + 0.001*"japan" + 0.001*"season" + 0.001*"israel" + 0.001*"emperor" + 0.001*"japanese" + 0.001*"prime" + 0.001*"china"
# 2023-04-04 14:48:44,800 : INFO : topic #5 (0.091): 0.027*"as" + 0.001*"soviet" + 0.001*"chinese" + 0.001*"ford" + 0.001*"km" + 0.001*"actor" + 0.001*"y" + 0.001*"economy" + 0.001*"software" + 0.001*"la"
# 2023-04-04 14:48:44,803 : INFO : topic #0 (0.091): 0.029*"as" + 0.001*"jewish" + 0.001*"love" + 0.001*"km" + 0.001*"israel" + 0.001*"soviet" + 0.001*"japanese" + 0.001*"bc" + 0.001*"african" + 0.001*"italian"
# 2023-04-04 14:48:44,805 : INFO : topic #2 (0.091): 0.033*"as" + 0.001*"emperor" + 0.001*"actor" + 0.001*"software" + 0.001*"energy" + 0.001*"minister" + 0.001*"india" + 0.001*"bc" + 0.001*"prime" + 0.001*"league"
# 2023-04-04 14:48:44,808 : INFO : topic #10 (0.091): 0.032*"as" + 0.001*"software" + 0.001*"soviet" + 0.001*"km" + 0.001*"japanese" + 0.001*"italian" + 0.001*"china" + 0.001*"parliament" + 0.001*"jewish" + 0.001*"japan"
# 2023-04-04 14:48:44,812 : INFO : topic diff=1.045482, rho=1.000000
# 2023-04-04 14:49:17,312 : INFO : -9.159 per-word bound, 571.5 perplexity estimate based on a held-out corpus of 1701 documents with 4222006 words
# 2023-04-04 14:49:17,313 : INFO : PROGRESS: pass 1, at document #1701/1701
# 2023-04-04 14:49:28,204 : INFO : topic #10 (0.091): 0.033*"as" + 0.002*"software" + 0.001*"kong" + 0.001*"apple" + 0.001*"soviet" + 0.001*"hong" + 0.001*"mac" + 0.001*"japanese" + 0.001*"china" + 0.001*"chinese"
# 2023-04-04 14:49:28,207 : INFO : topic #6 (0.091): 0.025*"as" + 0.003*"import" + 0.002*"software" + 0.002*"internet" + 0.001*"y" + 0.001*"z" + 0.001*"programming" + 0.001*"aircraft" + 0.001*"linux" + 0.001*"digital"
# 2023-04-04 14:49:28,210 : INFO : topic #1 (0.091): 0.032*"as" + 0.002*"league" + 0.001*"season" + 0.001*"jewish" + 0.001*"km" + 0.001*"bc" + 0.001*"football" + 0.001*"india" + 0.001*"africa" + 0.001*"female"
# 2023-04-04 14:49:28,213 : INFO : topic #5 (0.091): 0.026*"as" + 0.002*"soviet" + 0.002*"ford" + 0.001*"km" + 0.001*"economy" + 0.001*"la" + 0.001*"chinese" + 0.001*"bbc" + 0.001*"independence" + 0.001*"aircraft"
# 2023-04-04 14:49:28,216 : INFO : topic #0 (0.091): 0.030*"as" + 0.002*"love" + 0.001*"jewish" + 0.001*"israel" + 0.001*"fiction" + 0.001*"band" + 0.001*"bc" + 0.001*"bible" + 0.001*"italian" + 0.001*"street"
# 2023-04-04 14:49:28,219 : INFO : topic diff=0.174116, rho=0.577350
# 2023-04-04 14:49:28,222 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=11, decay=0.5, chunksize=2000> in 91.91s', 'datetime': '2023-04-04T14:49:28.221486', 'gensim': '4.3.1', 'python': '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2023-04-04 14:49:28,226 : INFO : ensemble contains 9 models and 160 topics now
# 2023-04-04 14:49:28,251 : INFO : ensemble contains 10 models and 169 topics now
# 2023-04-04 14:49:28,276 : INFO : asymmetric distance matrix is outdated due to add_model
# 2023-04-04 14:49:28,278 : INFO : generating a 180 x 180 asymmetric distance matrix...
# 2023-04-04 14:49:40,389 : INFO : fitting the clustering model, using 5 for min_samples
# 2023-04-04 14:49:40,638 : INFO : generating stable topics, using 3 for min_cores
# 2023-04-04 14:49:40,640 : INFO : found 3 clusters
# 2023-04-04 14:49:40,665 : INFO : found 1 stable topics
# 2023-04-04 14:49:40,675 : INFO : generating classic gensim model representation based on results from the ensemble
# 2023-04-04 14:49:40,679 : INFO : using symmetric alpha at 1.0
# 2023-04-04 14:49:40,681 : INFO : using symmetric eta at 1.0
# 2023-04-04 14:49:40,688 : INFO : using serial LDA version on this node
# 2023-04-04 14:49:40,695 : INFO : running online (multi-pass) LDA training, 1 topics, 0 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-04-04 14:49:40,697 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2023-04-04 14:49:40,699 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=1, decay=0.5, chunksize=2000> in 0.00s', 'datetime': '2023-04-04T14:49:40.699362', 'gensim': '4.3.1', 'python': '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 180
# 1
