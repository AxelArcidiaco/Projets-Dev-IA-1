# %% [markdown]
# ## Workshop 1 - Decision Tree (src : https://scikit-learn.org/stable/modules/tree.html#classification)

# %%
# Importation de la classe tree de la bibliothèque sklearn (scikit-learn)
from sklearn import tree

# Création des training et test sets
X = [[0, 0], [1, 1]]
Y = [0, 1]

# Chargement du classifier d'arbe de décision de la classe tree
clf = tree.DecisionTreeClassifier()

# Ajustement du classifier à nos données
clf = clf.fit(X, Y)

# %%
# Test de fonctionnement 1 - résultat attendu : array([1])
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
# Test de fonctionnement 2 - résultat attendu : array([[0., 1.]])
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %% [markdown]
# # Application d'un arbre de décision sur le dataset iris de sklearn

# %%
# Importation des modules et bibliothèques Python
from sklearn.datasets import load_iris
from sklearn import tree

# Chargement du dataset iris
iris = load_iris()

# séparation des données du dataset iris en training et test set
X, y = iris.data, iris.target

# Chargement du modèle
clf = tree.DecisionTreeClassifier()

# Application du modèle au dataset iris
clf = clf.fit(X, y)

# %%
# Affichage de l'arbre de décision
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# Exporation de l'arbre de décision du dataset iris au format pdf

# %%
# Chargement de la bibliothèque graphviz
import graphviz

# 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=iris.feature_names, 
                                class_names=iris.target_names,
                                filled=True, rounded=True,  
                                special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# Exportation de l'arbre de décision du dataset iris en texte

# %%
# Importation des bibliothèques python
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

iris = load_iris()
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(iris.data, iris.target)
r = export_text(decision_tree, feature_names=iris['feature_names'])
print(r)
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- class: 1
# |   |--- petal width (cm) >  1.75
# |   |   |--- class: 2
